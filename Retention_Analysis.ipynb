# %%
import pandas as pd

# %%
hr_df=pd.read_csv('D:\datascienceforbusiness-master\hr_data.csv')

# %%
hr_df.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
hr_df.shape
# Out:
# (14999, 9)

# %%
hr_df.select_dtypes(exclude=['int','float']).columns
# Out:
# Index(['department', 'salary'], dtype='object')

# %%
hr_df['department'].unique()
# Out:
# array(['sales', 'accounting', 'hr', 'technical', 'support', 'management',
#        'IT', 'product_mng', 'marketing', 'RandD'], dtype=object)

# %%
hr_df['salary'].unique()
# Out:
# array(['low', 'medium', 'high'], dtype=object)

# %%
empy_satis=pd.read_excel('D:\datascienceforbusiness-master\employee_satisfaction_evaluation.xlsx')

# %%
empy_satis.head(3)
# Out:
#    EMPLOYEE #  satisfaction_level  last_evaluation
# 0        1003                0.38             0.53
# 1        1005                0.80             0.86
# 2        1486                0.11             0.88

# %%
main_df=hr_df.set_index('employee_id').join(empy_satis.set_index('EMPLOYEE #'))

# %%
main_df=main_df.reset_index()

# %%
main_df.isnull()
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0            False           False                 False               False
# 1            False           False                 False               False
# 2            False           False                 False               False
# 3            False           False                 False               False
# 4            False           False                 False               False
# ...            ...             ...                   ...                 ...
# 14994        False           False                 False               False
# 14995        False           False                 False               False
# 14996        False           False                 False               False
# 14997        False           False                 False               False
# 14998        False           False                 False               False
#
# ...

# %%
main_df.describe()
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years  satisfaction_level  \
# count   14999.000000  14999.000000           14999.000000        14972.000000
# mean        0.144610      0.238083               0.021268            0.612830
# ...

# %%
main_df.fillna(main_df.mean(), inplace=True)
# Out:
# C:\Users\Manish\AppData\Local\Temp/ipykernel_14168/1234004495.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   main_df.fillna(main_df.mean(), inplace=True)

# %%
main_df.head(3)
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
#
#    Work_accident  left  promotion_last_5years department  salary  \
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
#
#    satisfaction_level  last_evaluation
# 0                0.38             0.53
# 1                0.80             0.86
# 2                0.11             0.88

# %%
main_df.isnull().sum()
# Out:
# employee_id              0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# department               0
# salary                   0
# satisfaction_level       0
# last_evaluation          0
# dtype: int64

# %%
main_df
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 0             1003               2                   157                   3
# 1             1005               5                   262                   6
# 2             1486               7                   272                   4
# 3             1038               5                   223                   5
# 4             1057               2                   159                   3
# ...            ...             ...                   ...                 ...
# 14994        87670               2                   151                   3
# 14995        87673               2                   160                   3
# 14996        87679               2                   143                   3
# 14997        87681               6                   280                   4
# 14998        87684               2                   158                   3
#
# ...

# %%
main_df_final=main_df.drop(columns='employee_id')
main_df_final.head(3)
# Out:
#    number_project  average_montly_hours  time_spend_company  Work_accident  \
# 0               2                   157                   3              0
# 1               5                   262                   6              0
# 2               7                   272                   4              0
#
#    left  promotion_last_5years department  salary  satisfaction_level  \
# 0     1                      0      sales     low                0.38
# 1     1                      0      sales  medium                0.80
# 2     1                      0      sales  medium                0.11
#
#    last_evaluation
# 0             0.53
# 1             0.86
# 2             0.88

# %%
main_df_final.groupby('department').sum()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                     4683                248119                4256
# RandD                  3033                158030                2650
# accounting             2934                154292                2702
# hr                     2701                146828                2480
# management             2432                126787                2711
# marketing              3164                171073                3063
# product_mng            3434                180369                3135
# sales                 15634                831773               14631
# support                8479                447490                7563
# technical             10548                550793                9279
#
#              Work_accident  left  promotion_last_5years  satisfaction_level  \
# department
# IT                     164   273                      3           758.17283
# ...

# %%
main_df_final.groupby('department').mean()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                 3.816626            202.215974            3.468623
# RandD              3.853875            200.800508            3.367217
# accounting         3.825293            201.162973            3.522816
# hr                 3.654939            198.684709            3.355886
# management         3.860317            201.249206            4.303175
# marketing          3.687646            199.385781            3.569930
# product_mng        3.807095            199.965632            3.475610
# sales              3.776329            200.911353            3.534058
# support            3.803948            200.758188            3.393001
# technical          3.877941            202.497426            3.411397
#
#              Work_accident      left  promotion_last_5years  \
# department
# IT                0.133659  0.222494               0.002445
# ...

# %%
import matplotlib.pyplot as plt

# %%
# Data Claening and Preparation

# %%
categorial=['department','salary']

# %%
main_df_final=pd.get_dummies(main_df_final,columns=categorial,drop_first=True)

# %%
main_df_final.head(3)
# Out:
#    number_project  average_montly_hours  time_spend_company  Work_accident  \
# 0               2                   157                   3              0
# 1               5                   262                   6              0
# 2               7                   272                   4              0
#
#    left  promotion_last_5years  satisfaction_level  last_evaluation  \
# 0     1                      0                0.38             0.53
# 1     1                      0                0.80             0.86
# 2     1                      0                0.11             0.88
#
#    department_RandD  department_accounting  department_hr  \
# 0                 0                      0              0
# 1                 0                      0              0
# 2                 0                      0              0
#
#    department_management  department_marketing  department_product_mng  \
# 0                      0                     0                       0
# ...

# %%
main_df_final.shape
# Out:
# (14999, 19)
